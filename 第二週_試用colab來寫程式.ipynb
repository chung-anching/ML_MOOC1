# %%
1+1
# Out:
# 2

# %% [markdown]
# 初次使用
# * 支援markdown、latex
# * 哈

# %% [markdown]
# 1-8【實作】用Colab畫函數圖形

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(-2,2,5)

# %%
x
# Out:
# array([-2., -1.,  0.,  1.,  2.])

# %%
y = x**2

# %%
y
# Out:
# array([4., 1., 0., 1., 4.])

# %%
plt.plot(x,y)

# %%
x = np.linspace(-2,2,500)

# %%
y = x**2

# %%
plt.plot(x,y)

# %%
plt.xkcd()
#變卡通風格

# %%
plt.plot(x,y)

# %%
#練習
x = np.linspace(1,10,500)

# %%
y = np.sin(x)

# %%
plt.xkcd()
plt.plot(x,y)
